# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dict_avar = {'1000': {1: [2.45],
                      2: [2.385627],
                      4: [2.389773],
                      8: [2.126351],
                      16: [2.123946], 
                      24: [2.120802]},
             
             '10000': {1: [12.13232],
                      2: [10.891808],
                      4: [6.200403],
                      8: [3.15113],
                      16: [2.083347],
                      24: [1.498184]},
             
             '25000': {1: [37.1311],
                     2: [27.645058],
                     4: [14.891627],
                     8: [7.451563],
                     16: [4.432140],
                     24: [3.052368]
                    }, 

             '50000': {1: [168.44226],
                     2: [55.324918],
                     4: [28.507588],
                     8: [14.048658],
                     16: [8.498651],
                     24: [5.650313]
                    }
            }

# %%
result_dict_time = {}
for key, vals in dict_avar.items():
    if key not in result_dict_time:
        result_dict_time[key] = {}
    for k, v in vals.items():
        if k not in result_dict_time[key]:
            result_dict_time[key][k] = 0
        result_dict_time[key][k] = sum(dict_avar[key][k]) / len(dic~t_avar[key][k])

# %%
df_avat = pd.DataFrame().from_dict(result_dict_time).T
for row in df_avat.iterrows():
    print(row[1].index)
    plt.plot(row[1].index, row[1])
plt.legend(labels=df_avat.index)
plt.title("Optimization O3")
plt.xlabel("Num. of process")
plt.ylabel("Time in seconds")
plt.show()
# Out:
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')

# %%
result_dict_flops = {}
for key, vals in dict_avar.items():
    if key not in result_dict_flops:
        result_dict_flops[key] = {}
    for k, v in vals.items():
        if k not in result_dict_flops[key]:
            result_dict_flops[key][k] = 0
        result_dict_flops[key][k] = (int(key) * (0.001 / 0.0000000002) / (sum(dict_avar[key][k]) / len(dict_avar[key][k]))) / 10**9

# %%
df_flops = pd.DataFrame().from_dict(result_dict_flops).T
df_flops
# Out:
#              1         2         4          8          16         24
# 1000   2.040816  2.095885  2.092249   2.351446   2.354109   2.357599
# 10000  4.121223  4.590606  8.063992  15.867324  23.999843  33.373738
# 25000  3.366450  4.521604  8.393979  16.775004  28.203080  40.951812
# 50000  1.484188  4.518760  8.769595  17.795294  29.416433  44.245336

# %%
for row in df_flops.iterrows():
    print(row[1].index)
    plt.plot(row[1].index, row[1])
plt.legend(labels=df_flops.index)
plt.title("Optimization O3")
plt.xlabel("Num. of process")
plt.ylabel("GFLOPS")
plt.show()
# Out:
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')

# %%
dict_avar = {
             '10000': {1: [1.15445],
                      2: [0.8926],
                      4: [0.49],
                      8: [0.2],
                      16: [0.1],
                      24: [0.08]},
             
             '25000': {1: [18.83133],
                     2: [8.71944],
                     4: [4.58992],
                     8: [2.57972],
                     16: [1.44740],
                     24: [1.08588]
                    }, 

             '50000': {1: [134.70047],
                     2: [67.59606],
                     4: [35.25594],
                     8: [20.00916],
                     16: [10.86643],
                     24: [7.46758]
                    }
            }

# %%
result_dict_time = {}
for key, vals in dict_avar.items():
    if key not in result_dict_time:
        result_dict_time[key] = {}
    for k, v in vals.items():
        if k not in result_dict_time[key]:
            result_dict_time[key][k] = 0
        result_dict_time[key][k] = sum(dict_avar[key][k]) / len(dict_avar[key][k])

# %%
df_avat = pd.DataFrame().from_dict(result_dict_time).T
for row in df_avat.iterrows():
    print(row[1].index)
    plt.plot(row[1].index, row[1])
plt.legend(labels=df_avat.index)
plt.title("Optimization O3")
plt.xlabel("Num. of process")
plt.ylabel("Time in seconds")
plt.show()
# Out:
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')

# %%
result_dict_flops = {}
for key, vals in dict_avar.items():
    if key not in result_dict_flops:
        result_dict_flops[key] = {}
    for k, v in vals.items():
        if k not in result_dict_flops[key]:
            result_dict_flops[key][k] = 0
        H = 1 / (int(key) - 1)
        TAU = 0.025 * H * H
        T1 = 0.0001
        result_dict_flops[key][k] = (int(key) * (T1 / TAU) / (sum(dict_avar[key][k]) / len(dict_avar[key][k]))) / 10**9

# %%
df_flops = pd.DataFrame().from_dict(result_dict_flops).T
df_flops
# Out:
#              1         2          4          8          16         24
# 10000  3.464160  4.480394   8.161633  19.996000  39.992000  49.990001
# 25000  3.318672  7.167318  13.615706  24.225497  43.177422  57.552400
# 50000  3.711791  7.396585  14.181440  24.987556  46.011432  66.953417

# %%
df_avat = pd.DataFrame().from_dict(result_dict_time).T
for row in df_flops.iterrows():
    print(row[1].index)
    plt.plot(row[1].index, row[1])
plt.legend(labels=df_flops.index)
plt.title("Optimization O3")
plt.xlabel("Num. of process")
plt.ylabel("GFLOPS")
plt.show()
# Out:
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
# Index([1, 2, 4, 8, 16, 24], dtype='int64')
